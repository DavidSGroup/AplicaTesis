# %%
import music21 as m21
# Supongamos que tienes un archivo de texto llamado "melody.txt"
archivo = "C:/Users/Davids/Documents/AplicaTesis/4lstmcompas/melodia.txt"

# Cargar la melodía desde el archivo
with open(archivo, "r") as file:
    melody = file.read().strip().split()  # Suponiendo que los símbolos están separados por espacios
 # create a music21 stream
stream = m21.stream.Stream()
# Add the 6/8 time signature at the beginning of the stream
time_signature = m21.meter.TimeSignature('6/8')
stream.append(time_signature)
start_symbol = None
step_duration=0.125
step_counter = 1
print(len(melody))
# Iterar sobre la melodía
for i, symbol in enumerate(melody):
    print(f"En el índice {i}, el símbolo es {symbol}")    
    # handle case in which we have a note/res 
    print("___:",{symbol})
    if symbol != "_" or i + 1 == len(melody):
        # ensure we're dealing with note/rest beyond the first one
        if start_symbol is not None:
            quarter_length_duration = step_duration * step_counter # 0.25 * 4 = 1
            print("stepcounter: ",{step_counter})
            print("duracion total",{quarter_length_duration})
            # handle rest
            if start_symbol == "r":
                m21_event = m21.note.Rest(quarterLength=quarter_length_duration)
                # handle note
            else:
                #aqui es donde ingresa la nota
                m21_event = m21.note.Note(int(start_symbol), quarterLength=(quarter_length_duration/2))
            stream.append(m21_event)
        # reset the step counter
            step_counter = 1
        start_symbol = symbol
        print("start:.",start_symbol)

      # handle case in which we have a prolongation sign "_"
    else:
        step_counter += 1
stream.show()
# Out:
# 102
# En el índice 0, el símbolo es 67
# ___: {'67'}
# start:. 67
# En el índice 1, el símbolo es _
# ___: {'_'}
# En el índice 2, el símbolo es _
# ___: {'_'}
# En el índice 3, el símbolo es _
# ___: {'_'}
# En el índice 4, el símbolo es _
# ___: {'_'}
# En el índice 5, el símbolo es _
# ___: {'_'}
# En el índice 6, el símbolo es _
# ___: {'_'}
# En el índice 7, el símbolo es _
# ___: {'_'}
# En el índice 8, el símbolo es _
# ___: {'_'}
# En el índice 9, el símbolo es _
# ___: {'_'}
# En el índice 10, el símbolo es _
# ___: {'_'}
# En el índice 11, el símbolo es _
# ___: {'_'}
# En el índice 12, el símbolo es 65
# ___: {'65'}
# stepcounter:  {12}
# duracion total {1.5}
# start:. 65
# En el índice 13, el símbolo es _
# ___: {'_'}
# En el índice 14, el símbolo es _
# ___: {'_'}
# En el índice 15, el símbolo es _
# ___: {'_'}
# En el índice 16, el símbolo es 64
# ___: {'64'}
# stepcounter:  {4}
# duracion total {0.5}
# start:. 64
# En el índice 17, el símbolo es _
# ___: {'_'}
# ...

# %%
import music21 as m21

def handle_symbol(stream, symbol, start_symbol, step_duration, step_counter):
   # print(f"stream: {stream}, symbol: {symbol}, start_symbol: {start_symbol}, step_duration: {step_duration}, step_counter: {step_counter}")
    
    if symbol != "_" or i + 1 == len(melody):
        if start_symbol is not None:
            quarter_length_duration = step_duration * step_counter
            print(quarter_length_duration)
            m21_event = create_music21_event(start_symbol, quarter_length_duration)
            stream.append(m21_event)
            step_counter = 1
        start_symbol = symbol
    else:
        step_counter += 1
    print(step_counter)   

def create_music21_event(symbol, duration):
    if symbol == "r":
        return m21.note.Rest(quarterLength=duration)
    else:
        return m21.note.Note(int(symbol), quarterLength=duration)

def process_melody(melody):
    stream = m21.stream.Stream()
    time_signature = m21.meter.TimeSignature('6/8')
    stream.append(time_signature)
    
    start_symbol = None
    step_duration = 0.125
    step_counter = 1

    for i, symbol in enumerate(melody):
        handle_symbol(stream, symbol, start_symbol, step_duration, step_counter)
    
    return stream

# Supongamos que tienes un archivo de texto llamado "melody.txt"
archivo = "C:/Users/Davids/Documents/AplicaTesis/4lstmcompas/melodia.txt"

# Cargar la melodía desde el archivo
with open(archivo, "r") as file:
    melody = file.read().strip().split()  # Suponiendo que los símbolos están separados por espacios

# Crear un Stream a partir de la melodía
melody_stream = process_melody(melody)

# Imprimir la representación de la melodía en music21
melody_stream.show()
# Out:
# 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 46
#      43     melody = file.read().strip().split()  # Suponiendo que los símbolos están separados por espacios
#      45 # Crear un Stream a partir de la melodía
# ---> 46 melody_stream = process_melody(melody)
#      48 # Imprimir la representación de la melodía en music21
#      49 melody_stream.show()
#
# Cell In[1], line 34, in process_melody(melody)
#      31 step_counter = 1
#      33 for i, symbol in enumerate(melody):
# ---> 34     handle_symbol(stream, symbol, start_symbol, step_duration, step_counter)
#      36 return stream
#
# Cell In[1], line 6, in handle_symbol(stream, symbol, start_symbol, step_duration, step_counter)
#       3 def handle_symbol(stream, symbol, start_symbol, step_duration, step_counter):
# ...

# %%
import re
# Inicializa variab
archivo = "C:/Users/Davids/Documents/AplicaTesis/4lstmcompas/melodia.txt"


def procesar_archivo(archivo, archivo_salida):
    # Abre el archivo de entrada en modo lectura
    with open(archivo, 'r') as entrada:
        # Lee todas las líneas del archivo
        lineas = entrada.readlines()

    # Abre el archivo de salida en modo escritura
    with open(archivo_salida, 'w') as salida:
        # Itera sobre cada línea del archivo de entrada
        for linea in lineas:
            # Busca todos los números en la línea
            numeros = re.findall(r'\d+', linea)

            # Si se encuentran números, agrega un retorno de carro después de cada uno
            if numeros:
                for numero in numeros:
                    print(numero)
                    linea = linea.replace(numero, numero + '\n')
                

            # Escribe la línea procesada en el archivo de salida
            salida.write(linea)

# Ejemplo de uso


procesar_archivo(archivo, archivo_salida)
# Out:
# 67
# 67
# ...

# %%
import re

archivo = "C:/Users/Davids/Documents/AplicaTesis/4lstmcompas/melodia.txt"

def contar_antes_de_numeros(archivo):
    with open(archivo, 'r') as file:
        contenido = file.read()

        # Encuentra todos los números en el contenido
        numeros = [int(numero) for numero in re.findall(r'\d+', contenido)]

        # Inicializa el array para almacenar los recuentos
        recuentos_underscore = []

        # Inicializa el contador de '_' antes del primer número
        contador_underscore = 0

        for caracter in contenido:
            if caracter == '_':
                contador_underscore += 1
            elif caracter.isdigit():
                recuentos_underscore.append(contador_underscore)
                contador_underscore = 0

        # Imprime el array de recuentos
        print("Array de recuentos de '_':", recuentos_underscore)
        array_sin_ceros = list(filter(lambda x: x != 0, recuentos_underscore))
        print("Array de  '_':", array_sin_ceros)
        array_modificado = list(map(lambda x: x + 1, array_sin_ceros))
        print("Array de  '_':", array_modificado)
        

# Ejemplo de uso
contar_antes_de_numeros(archivo)
# Out:
# Array de recuentos de '_': [0, 0, 11, 0, 3, 0, 7, 0, 7, 0, 7, 0, 3, 0, 3, 0, 7, 0, 7, 0, 11, 0, 7, 0, 3, 0, 7, 0, 3, 0, 7, 0, 3, 0, 7, 0, 3, 0, 7, 0, 3, 0, 7, 0, 3, 0, 11, 0, 7, 0, 3, 0, 7, 0, 3, 0, 7, 0, 3, 0, 7, 0, 3, 0, 7, 0, 3, 0, 7, 0, 3, 0, 7, 0, 3, 0, 11, 0, 7, 0, 3, 0, 7, 0, 3, 0, 7, 0, 3, 0, 7, 0, 3, 0, 7, 0, 3, 0, 7, 0, 3, 0, 7, 0, 3, 0, 7, 0, 3, 0, 7, 0, 3, 0, 7, 0, 3, 0]
# Array de  '_': [11, 3, 7, 7, 7, 3, 3, 7, 7, 11, 7, 3, 7, 3, 7, 3, 7, 3, 7, 3, 7, 3, 11, 7, 3, 7, 3, 7, 3, 7, 3, 7, 3, 7, 3, 7, 3, 11, 7, 3, 7, 3, 7, 3, 7, 3, 7, 3, 7, 3, 7, 3, 7, 3, 7, 3, 7, 3]
# Array de  '_': [12, 4, 8, 8, 8, 4, 4, 8, 8, 12, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 12, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 12, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4]
