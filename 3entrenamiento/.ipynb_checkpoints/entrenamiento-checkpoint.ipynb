# %%
logger="win10Davids"
import sys
sys.path.append('C:/Users/{}/Documents/AplicaTesis/2preprocesamiento'.format(logger))
#from preprocesamiento import generate_training_sequences, SEQUENCE_LENGTH,MAPPING_PATH
from preprocesamiento import gtraining_sequences, SQ_LENGTH,DICTIO_PATH

print(SQ_LENGTH)
print(DICTIO_PATH)
# Out:
# 64
# c:/Users/win10Davids/Documents/AplicaTesis/1DICCIONARIO/dictiocueca.json

# %%
import json

# Leer el contenido del archivo JSON
with open(DICTIO_PATH, 'r') as file:
    contenido_json = json.load(file)

# Obtener el total de elementos en el diccionario
total_elementos = len(contenido_json)

print(f"El archivo '{DICTIO_PATH}' contiene un total de {total_elementos} elementos.")
# Out:
# El archivo 'c:/Users/win10Davids/Documents/AplicaTesis/1DICCIONARIO/dictiocueca.json' contiene un total de 48 elementos.

# %%
import json
import numpy as np
import tensorflow.keras as keras
#48erk,
OUTPUT_UNITS = 48
NUM_UNITS = [256]
LOSS = "sparse_categorical_crossentropy"
LEARNING_RATE = 0.001
EPOCHS =50       #50
BATCH_SIZE = 64
ROUTE_MODEL= "C:/Users/{}/Documents/AplicaTesis/3MODELO/cuecapura1.h5".format(logger)

# %%
def build_model(output_units, num_units, loss, learning_rate):

    # create the model architecture
    input = keras.layers.Input(shape=(None, output_units))
    #input = keras.layers.Input(shape=(timesteps, input_features))
    x = keras.layers.LSTM(num_units[0])(input)
    x = keras.layers.Dropout(0.2)(x)

    output = keras.layers.Dense(output_units, activation="softmax")(x)

    model = keras.Model(input, output)

    # compile model
    model.compile(loss=loss,
                  optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
                  metrics=["accuracy"])

    model.summary()

    return model

# %%
def develop_model(output_units=OUTPUT_UNITS, num_units=NUM_UNITS, loss=LOSS, learning_rate=LEARNING_RATE):
  
    # generate the training sequences
    
    inputs, targets = gtraining_sequences(SQ_LENGTH)

    # build the network
    model = build_model(output_units, num_units, loss, learning_rate)

    # train the model
    model.fit(inputs, targets, epochs=EPOCHS, batch_size=BATCH_SIZE)
    #perdidas y precision
    resultados = model.evaluate(inputs, targets, verbose=0)

    # Obtener la pérdida y precisión
    perdida = resultados[0]
    precision = resultados[1]

    # Imprimir la pérdida y precisión en porcentaje
    print(f'Pérdida: {perdida:.2f}')
    print(f'Precisión: {precision * 100:.2f}%')

    # save the model
    model.save(ROUTE_MODEL)

# %%
if __name__ == "__main__":
    develop_model()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, 48)]        0
#
#  lstm (LSTM)                 (None, 256)               312320
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 48)                12336
#
# =================================================================
# Total params: 324656 (1.24 MB)
# Trainable params: 324656 (1.24 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 338/338 [==============================] - 42s 117ms/step - loss: 1.0256 - accuracy: 0.8285
# Epoch 2/50
# 338/338 [==============================] - 39s 116ms/step - loss: 0.8640 - accuracy: 0.8468
# Epoch 3/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.7266 - accuracy: 0.8475
# Epoch 4/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.6816 - accuracy: 0.8485
# Epoch 5/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.6659 - accuracy: 0.8484
# Epoch 6/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.6361 - accuracy: 0.8485
# Epoch 7/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.5867 - accuracy: 0.8491
# Epoch 8/50
# 338/338 [==============================] - 39s 116ms/step - loss: 0.5424 - accuracy: 0.8500
# Epoch 9/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.5220 - accuracy: 0.8521
# Epoch 10/50
# 338/338 [==============================] - 39s 114ms/step - loss: 0.5080 - accuracy: 0.8516
# Epoch 11/50
# 338/338 [==============================] - 40s 117ms/step - loss: 0.4984 - accuracy: 0.8537
# Epoch 12/50
# 338/338 [==============================] - 39s 114ms/step - loss: 0.4877 - accuracy: 0.8565
# Epoch 13/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.4771 - accuracy: 0.8570
# Epoch 14/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.4666 - accuracy: 0.8597
# Epoch 15/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.4598 - accuracy: 0.8602
# Epoch 16/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.4462 - accuracy: 0.8649
# Epoch 17/50
# 338/338 [==============================] - 40s 118ms/step - loss: 0.4373 - accuracy: 0.8676
# Epoch 18/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.4286 - accuracy: 0.8682
# Epoch 19/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.4321 - accuracy: 0.8703
# Epoch 20/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.4917 - accuracy: 0.8560
# Epoch 21/50
# 338/338 [==============================] - 39s 114ms/step - loss: 0.4304 - accuracy: 0.8690
# Epoch 22/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.4085 - accuracy: 0.8745
# Epoch 23/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.3948 - accuracy: 0.8804
# Epoch 24/50
# 338/338 [==============================] - 39s 116ms/step - loss: 0.3841 - accuracy: 0.8837
# Epoch 25/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.3716 - accuracy: 0.8884
# Epoch 26/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.3639 - accuracy: 0.8899
# Epoch 27/50
# 338/338 [==============================] - 39s 116ms/step - loss: 0.3602 - accuracy: 0.8915
# Epoch 28/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.3433 - accuracy: 0.8956
# Epoch 29/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.3372 - accuracy: 0.8967
# Epoch 30/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.3262 - accuracy: 0.8991
# Epoch 31/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.3239 - accuracy: 0.9022
# Epoch 32/50
# 338/338 [==============================] - 39s 115ms/step - loss: 0.3096 - accuracy: 0.9052
# Epoch 33/50
# 338/338 [==============================] - 39s 116ms/step - loss: 0.2979 - accuracy: 0.9094
# Epoch 34/50
# 338/338 [==============================] - 39s 116ms/step - loss: 0.2892 - accuracy: 0.9101
# Epoch 35/50
# 338/338 [==============================] - 39s 116ms/step - loss: 0.2813 - accuracy: 0.9128
# Epoch 36/50
# 338/338 [==============================] - 39s 116ms/step - loss: 0.2696 - accuracy: 0.9180
# Epoch 37/50
# 338/338 [==============================] - 39s 117ms/step - loss: 0.2580 - accuracy: 0.9205
# Epoch 38/50
# 338/338 [==============================] - 39s 116ms/step - loss: 0.2517 - accuracy: 0.9223
# Epoch 39/50
# 338/338 [==============================] - 40s 119ms/step - loss: 0.2432 - accuracy: 0.9273
# Epoch 40/50
# 338/338 [==============================] - 40s 118ms/step - loss: 0.2364 - accuracy: 0.9262
# Epoch 41/50
# 338/338 [==============================] - 39s 116ms/step - loss: 0.2238 - accuracy: 0.9314
# Epoch 42/50
# 338/338 [==============================] - 39s 116ms/step - loss: 0.2171 - accuracy: 0.9323
# Epoch 43/50
# 338/338 [==============================] - 39s 116ms/step - loss: 0.2039 - accuracy: 0.9360
# Epoch 44/50
# 338/338 [==============================] - 39s 116ms/step - loss: 0.1940 - accuracy: 0.9393
# Epoch 45/50
# 338/338 [==============================] - 40s 117ms/step - loss: 0.1885 - accuracy: 0.9410
# Epoch 46/50
# 338/338 [==============================] - 39s 116ms/step - loss: 0.1828 - accuracy: 0.9423
# Epoch 47/50
# 338/338 [==============================] - 39s 116ms/step - loss: 0.1853 - accuracy: 0.9416
# Epoch 48/50
# 338/338 [==============================] - 42s 124ms/step - loss: 0.1674 - accuracy: 0.9470
# Epoch 49/50
# 338/338 [==============================] - 38s 113ms/step - loss: 0.1540 - accuracy: 0.9513
# Epoch 50/50
# 338/338 [==============================] - 39s 116ms/step - loss: 0.1694 - accuracy: 0.9478
# Pérdida: 0.12
# Precisión: 96.42%
# C:\Users\Davids\anaconda3\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
